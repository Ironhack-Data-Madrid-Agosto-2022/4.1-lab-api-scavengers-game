# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
#pip install python-dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
file = '/Users/carlosbasco/Desktop/Labs/Lab EDA 29_08/4.1-lab-api-scavengers-game/pass/pass.txt'

# %%
pswrd = ''
with open(file) as archivo:
    pswrd = archivo.readline().rstrip('\n')

# %%
def requestGithub (pswrd, endpoint):
    
    
    '''This function get an endopoint as argument and returns a list with the response from GitHub API.
    It imports the github token from the .env file(not uploaded to github) and gets the authentication ready.s
    If you don't have your token in the .env file, it will raise an error.
    The function takes the base url https://api.github.com for github API and adds the endpoint that gets as argument'''
    
    
    token = pswrd
    if not token:
        raise ValueError ("Necesitas un token")
    direccion="https://api.github.com"
    url = direccion+endpoint

    print(f"Haciendo request a {url}")
    headers = {
        "Authorization": token}

    res = requests.get(url, headers=headers)
    return res.json()

# %%
file_json = requestGithub(pswrd,"/repos/Ironhack-Data-Madrid-Agosto-2022/4.1-lab-api-scavengers-game/forks")
# Out:
# Haciendo request a https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/4.1-lab-api-scavengers-game/forks

# %%
file_json
# Out:
# [{'id': 530241315,
#   'node_id': 'R_kgDOH5rXIw',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'joserojas95/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'joserojas95',
#    'id': 110819726,
#    'node_id': 'U_kgDOBpr5jg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110819726?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joserojas95',
#    'html_url': 'https://github.com/joserojas95',
#    'followers_url': 'https://api.github.com/users/joserojas95/followers',
#    'following_url': 'https://api.github.com/users/joserojas95/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joserojas95/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joserojas95/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joserojas95/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joserojas95/orgs',
#    'repos_url': 'https://api.github.com/users/joserojas95/repos',
#    'events_url': 'https://api.github.com/users/joserojas95/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joserojas95/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/joserojas95/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/joserojas95/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:51:26Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/joserojas95/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:joserojas95/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/joserojas95/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/joserojas95/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530230071,
#   'node_id': 'R_kgDOH5qrNw',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'JaimeLeoz/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'JaimeLeoz',
#    'id': 109471127,
#    'node_id': 'U_kgDOBoZllw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109471127?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JaimeLeoz',
#    'html_url': 'https://github.com/JaimeLeoz',
#    'followers_url': 'https://api.github.com/users/JaimeLeoz/followers',
#    'following_url': 'https://api.github.com/users/JaimeLeoz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JaimeLeoz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JaimeLeoz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JaimeLeoz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JaimeLeoz/orgs',
#    'repos_url': 'https://api.github.com/users/JaimeLeoz/repos',
#    'events_url': 'https://api.github.com/users/JaimeLeoz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JaimeLeoz/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JaimeLeoz/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/JaimeLeoz/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:23:12Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/JaimeLeoz/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:JaimeLeoz/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/JaimeLeoz/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/JaimeLeoz/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530228996,
#   'node_id': 'R_kgDOH5qnBA',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'Davidmcii/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'Davidmcii',
#    'id': 109244436,
#    'node_id': 'U_kgDOBoLwFA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109244436?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Davidmcii',
#    'html_url': 'https://github.com/Davidmcii',
#    'followers_url': 'https://api.github.com/users/Davidmcii/followers',
#    'following_url': 'https://api.github.com/users/Davidmcii/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Davidmcii/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Davidmcii/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Davidmcii/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Davidmcii/orgs',
#    'repos_url': 'https://api.github.com/users/Davidmcii/repos',
#    'events_url': 'https://api.github.com/users/Davidmcii/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Davidmcii/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Davidmcii/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Davidmcii/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:20:40Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/Davidmcii/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:Davidmcii/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/Davidmcii/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/Davidmcii/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530228963,
#   'node_id': 'R_kgDOH5qm4w',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'PabloGR1/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'PabloGR1',
#    'id': 107139579,
#    'node_id': 'U_kgDOBmLR-w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107139579?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PabloGR1',
#    'html_url': 'https://github.com/PabloGR1',
#    'followers_url': 'https://api.github.com/users/PabloGR1/followers',
#    'following_url': 'https://api.github.com/users/PabloGR1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PabloGR1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PabloGR1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PabloGR1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PabloGR1/orgs',
#    'repos_url': 'https://api.github.com/users/PabloGR1/repos',
#    'events_url': 'https://api.github.com/users/PabloGR1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PabloGR1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/PabloGR1/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/PabloGR1/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:20:35Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/PabloGR1/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:PabloGR1/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/PabloGR1/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/PabloGR1/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530228368,
#   'node_id': 'R_kgDOH5qkkA',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'Carlosbasco93/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'Carlosbasco93',
#    'id': 107916116,
#    'node_id': 'U_kgDOBm6rVA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107916116?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Carlosbasco93',
#    'html_url': 'https://github.com/Carlosbasco93',
#    'followers_url': 'https://api.github.com/users/Carlosbasco93/followers',
#    'following_url': 'https://api.github.com/users/Carlosbasco93/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Carlosbasco93/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Carlosbasco93/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Carlosbasco93/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Carlosbasco93/orgs',
#    'repos_url': 'https://api.github.com/users/Carlosbasco93/repos',
#    'events_url': 'https://api.github.com/users/Carlosbasco93/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Carlosbasco93/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Carlosbasco93/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Carlosbasco93/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:19:09Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/Carlosbasco93/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:Carlosbasco93/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/Carlosbasco93/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/Carlosbasco93/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530228118,
#   'node_id': 'R_kgDOH5qjlg',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'ecamposgo/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'ecamposgo',
#    'id': 110788507,
#    'node_id': 'U_kgDOBpp_mw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110788507?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ecamposgo',
#    'html_url': 'https://github.com/ecamposgo',
#    'followers_url': 'https://api.github.com/users/ecamposgo/followers',
#    'following_url': 'https://api.github.com/users/ecamposgo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ecamposgo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ecamposgo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ecamposgo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ecamposgo/orgs',
#    'repos_url': 'https://api.github.com/users/ecamposgo/repos',
#    'events_url': 'https://api.github.com/users/ecamposgo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ecamposgo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/ecamposgo/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ecamposgo/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:18:30Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/ecamposgo/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:ecamposgo/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/ecamposgo/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/ecamposgo/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530226878,
#   'node_id': 'R_kgDOH5qevg',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'antlopal3rd/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'antlopal3rd',
#    'id': 108612580,
#    'node_id': 'U_kgDOBnlL5A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108612580?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antlopal3rd',
#    'html_url': 'https://github.com/antlopal3rd',
#    'followers_url': 'https://api.github.com/users/antlopal3rd/followers',
#    'following_url': 'https://api.github.com/users/antlopal3rd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/antlopal3rd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/antlopal3rd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/antlopal3rd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/antlopal3rd/orgs',
#    'repos_url': 'https://api.github.com/users/antlopal3rd/repos',
#    'events_url': 'https://api.github.com/users/antlopal3rd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/antlopal3rd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/antlopal3rd/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/antlopal3rd/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:15:18Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/antlopal3rd/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:antlopal3rd/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/antlopal3rd/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/antlopal3rd/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530226384,
#   'node_id': 'R_kgDOH5qc0A',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'Vert-ix/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'Vert-ix',
#    'id': 108289867,
#    'node_id': 'U_kgDOBnRfSw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108289867?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vert-ix',
#    'html_url': 'https://github.com/Vert-ix',
#    'followers_url': 'https://api.github.com/users/Vert-ix/followers',
#    'following_url': 'https://api.github.com/users/Vert-ix/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Vert-ix/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Vert-ix/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Vert-ix/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Vert-ix/orgs',
#    'repos_url': 'https://api.github.com/users/Vert-ix/repos',
#    'events_url': 'https://api.github.com/users/Vert-ix/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Vert-ix/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Vert-ix/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Vert-ix/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T13:13:57Z',
#   'updated_at': '2022-08-29T08:32:43Z',
# ...
#   'git_tags_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/AtomLu/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T11:12:17Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/AtomLu/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:AtomLu/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/AtomLu/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/AtomLu/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530177267,
#   'node_id': 'R_kgDOH5nc8w',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'Miguelmotacava/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'Miguelmotacava',
#    'id': 109019847,
#    'node_id': 'U_kgDOBn-Cxw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109019847?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Miguelmotacava',
#    'html_url': 'https://github.com/Miguelmotacava',
#    'followers_url': 'https://api.github.com/users/Miguelmotacava/followers',
#    'following_url': 'https://api.github.com/users/Miguelmotacava/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Miguelmotacava/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Miguelmotacava/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Miguelmotacava/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Miguelmotacava/orgs',
#    'repos_url': 'https://api.github.com/users/Miguelmotacava/repos',
#    'events_url': 'https://api.github.com/users/Miguelmotacava/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Miguelmotacava/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Miguelmotacava/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Miguelmotacava/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T10:51:40Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/Miguelmotacava/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:Miguelmotacava/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/Miguelmotacava/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/Miguelmotacava/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 530175263,
#   'node_id': 'R_kgDOH5nVHw',
#   'name': '4.1-lab-api-scavengers-game',
#   'full_name': 'LuCostilla/4.1-lab-api-scavengers-game',
#   'private': False,
#   'owner': {'login': 'LuCostilla',
#    'id': 110810531,
#    'node_id': 'U_kgDOBprVow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110810531?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuCostilla',
#    'html_url': 'https://github.com/LuCostilla',
#    'followers_url': 'https://api.github.com/users/LuCostilla/followers',
#    'following_url': 'https://api.github.com/users/LuCostilla/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LuCostilla/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LuCostilla/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LuCostilla/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LuCostilla/orgs',
#    'repos_url': 'https://api.github.com/users/LuCostilla/repos',
#    'events_url': 'https://api.github.com/users/LuCostilla/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LuCostilla/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/LuCostilla/4.1-lab-api-scavengers-game',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game',
#   'forks_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/forks',
#   'keys_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/teams',
#   'hooks_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/hooks',
#   'issue_events_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/events',
#   'assignees_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/tags',
#   'blobs_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/languages',
#   'stargazers_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/stargazers',
#   'contributors_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/contributors',
#   'subscribers_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/subscribers',
#   'subscription_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/subscription',
#   'commits_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/merges',
#   'archive_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/downloads',
#   'issues_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/LuCostilla/4.1-lab-api-scavengers-game/deployments',
#   'created_at': '2022-08-29T10:45:37Z',
#   'updated_at': '2022-08-29T08:32:43Z',
#   'pushed_at': '2022-08-29T08:32:40Z',
#   'git_url': 'git://github.com/LuCostilla/4.1-lab-api-scavengers-game.git',
#   'ssh_url': 'git@github.com:LuCostilla/4.1-lab-api-scavengers-game.git',
#   'clone_url': 'https://github.com/LuCostilla/4.1-lab-api-scavengers-game.git',
#   'svn_url': 'https://github.com/LuCostilla/4.1-lab-api-scavengers-game',
#   'homepage': None,
#   'size': 87,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]
