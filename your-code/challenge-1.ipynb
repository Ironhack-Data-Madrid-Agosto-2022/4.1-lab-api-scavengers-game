# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
# Out:
# True

# %%
github = os.getenv("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")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as req

# %%
url='https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase'

# %%
iron = req.get(url)

# %%
iron.json().keys()
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'l
# ...

# %%
iron.json()['language']
# Out:
# 'Jupyter Notebook'

# %%
headers = {"Authorization": f"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"}

# %%
endpoint='/repos/Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase'
res = requests.get(url, headers=headers)

# %%
def requestGithub(endpoint):    
    
    token = os.getenv("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")
    if not token:
        raise ValueError ("Necesitas un token")
    direccion="https://api.github.com"
    url = 'https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase'

    print(f"Haciendo request a {url}")
    headers = {
        "Authorization": f"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"}

    res = requests.get(url, headers=headers)
    return res.json()

# %%
res.json().keys()
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'l
# ...

# %%
res.json()['language']
# Out:
# 'Jupyter Notebook'

# %%
url_2= 'https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/2.4-lab-data-cleaning/forks'

# %%
res = req.get(url_2, headers = {"Authorization":"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"})

# %%
res.json()
# Out:
# [{'id': 526306141,
#   'node_id': 'R_kgDOH17LXQ',
#   'name': '2.4-lab-data-cleaning',
#   'full_name': 'javiercanela3/2.4-lab-data-cleaning',
#   'private': False,
#   'owner': {'login': 'javiercanela3',
#    'id': 72074430,
#    'node_id': 'MDQ6VXNlcjcyMDc0NDMw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72074430?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/javiercanela3',
#    'html_url': 'https://github.com/javiercanela3',
#    'followers_url': 'https://api.github.com/users/javiercanela3/followers',
#    'following_url': 'https://api.github.com/users/javiercanela3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/javiercanela3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/javiercanela3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/javiercanela3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/javiercanela3/orgs',
# ...

# %%
lang= res.json()

# %%
len(lang)
# Out:
# 17

# %%
languages =[]

for i in lang:
    languages.append(i['language'])
    
languages
# Out:
# ['Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']
