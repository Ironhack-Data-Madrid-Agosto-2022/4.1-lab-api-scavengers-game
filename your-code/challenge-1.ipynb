# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
# %pip install python-dotenv

# %%
load_dotenv()
# Out:
# True

# %%
github = os.getenv("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")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as req

# %%
def funcion(url):
    headers={'Authorization':'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'}
    response=req.get(url,headers=headers)
    return response.json()

# %% [markdown]
# # Primera búsqueda

# %%
url='https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase'

# %%
res=req.get(url)

# %%
res.json()
# Out:
# {'id': 520583229,
#  'node_id': 'R_kgDOHwd4PQ',
#  'name': 'Apuntes-de-clase',
#  'full_name': 'Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase',
#  'private': False,
#  'owner': {'login': 'Ironhack-Data-Madrid-Agosto-2022',
#   'id': 110230736,
#   'node_id': 'O_kgDOBpH80A',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/110230736?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Ironhack-Data-Madrid-Agosto-2022',
#   'html_url': 'https://github.com/Ironhack-Data-Madrid-Agosto-2022',
#   'followers_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Agosto-2022/followers',
#   'following_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Agosto-2022/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Agosto-2022/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Ironhack-Data-Madrid-Agosto-2022/starred{/owner}{/repo}',
# ...

# %%
res.json()['language']
# Out:
# 'Jupyter Notebook'

# %% [markdown]
# # Solución: segunda búsqueda

# %%
url3='https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/3.4-lab-mongo/forks'

# %%
res=req.get(url3, headers={'Authorization':'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'})

# %%
res.json()
# Out:
# [{'id': 529155801,
#   'node_id': 'R_kgDOH4pG2Q',
#   'name': '3.4-lab-mongo',
#   'full_name': 'joserojas95/3.4-lab-mongo',
#   'private': False,
#   'owner': {'login': 'joserojas95',
#    'id': 110819726,
#    'node_id': 'U_kgDOBpr5jg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110819726?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joserojas95',
#    'html_url': 'https://github.com/joserojas95',
#    'followers_url': 'https://api.github.com/users/joserojas95/followers',
#    'following_url': 'https://api.github.com/users/joserojas95/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joserojas95/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joserojas95/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joserojas95/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joserojas95/orgs',
# ...

# %%
leng=res.json()

# %%
len(leng)
# Out:
# 17

# %%
lenguage=[]
for i in leng:
    lenguage.append(i['language'])
    
    
lenguage
# Out:
# ['Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']

# %%
type(lenguage)
# Out:
# list
