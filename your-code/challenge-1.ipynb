# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
pip install python-dotenv #solo instalar una vez
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
# Out:
# True

# %%
github = os.getenv("token")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
url = "https://api.github.com"

headers = {"Authorization": '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'}

res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
url_forks = 'https://api.github.com/repos/Ironhack-Data-Madrid-Agosto-2022/Apuntes-de-clase/forks'

# %%
res = requests.get(url_forks, headers=headers)

res
# Out:
# <Response [200]>

# %%
result = res.json()

# %%
result
# Out:
# [{'id': 530256513,
#   'node_id': 'R_kgDOH5sSgQ',
#   'name': 'Apuntes-de-clase',
#   'full_name': 'AtomLu/Apuntes-de-clase',
#   'private': False,
#   'owner': {'login': 'AtomLu',
#    'id': 93143274,
#    'node_id': 'U_kgDOBY1A6g',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93143274?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AtomLu',
#    'html_url': 'https://github.com/AtomLu',
#    'followers_url': 'https://api.github.com/users/AtomLu/followers',
#    'following_url': 'https://api.github.com/users/AtomLu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AtomLu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AtomLu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AtomLu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AtomLu/orgs',
#    'repos_url': 'https://api.github.com/users/AtomLu/repos',
# ...

# %%
len(result)
# Out:
# 8

# %%
languages = []
for i in range(len(result)):
    languages.append(res.json()[i]['language'])
languages
# Out:
# [None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook']
